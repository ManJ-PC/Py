# %% [markdown]
# <a href="https://colab.research.google.com/github/ManJ-PC/Py/blob/master/Selecting_rows_in_pandas_DataFrame_based_on_conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/master/employees.csv'

# %%
df = pd.read_csv(url)
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.isna().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df[df['Team'].isna()]
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 10        Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 23           NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 32           NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 91         James     NaN   1/26/2005        11:00 PM  128771    8.309
# 109  Christopher    Male   4/22/2000        10:15 AM   37919   11.449
# 139          NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 199     Jonathan    Male   7/17/2009         8:15 AM  130581   16.736
# 258      Michael    Male   1/24/2002         3:04 AM   43586   12.659
# 290       Jeremy    Male   6/14/1988         6:20 PM  129460   13.657
# 314        Bobby    Male   3/31/1996         5:40 PM  112117    6.338
# 367       Edward    Male    8/4/1989         6:06 AM   66067   10.957
# ...

# %%
df[df['Team'].isnull()].count()
# Out:
# First Name           34
# Gender               39
# Start Date           43
# Last Login Time      43
# Salary               43
# Bonus %              43
# Senior Management    34
# Team                  0
# dtype: int64

# %%
df[df['Team'].isnull()].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Start Date           3/31/19968/12/19806/14/20128/21/19981/26/20054...
# Last Login Time      6:53 AM9:01 AM4:19 PM2:27 PM11:00 PM10:15 AM1:...
# Salary                                                         3902815
# Bonus %                                                        446.529
# Senior Management                                                   18
# Team                                                                 0
# dtype: object

# %%
df[df.isna().any(axis=1)] # assinala todas as linhas que tem algum tipo de NA's+++++++++++++++++++++++
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 20        Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ..         ...     ...         ...             ...     ...      ...
# 961    Antonio     NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor     NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen     NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# ...

# %%
df[df.isnull().any(axis = 1)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 20        Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ..         ...     ...         ...             ...     ...      ...
# 961    Antonio     NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor     NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen     NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# ...

# %%
df3 = pd.DataFrame({"A": [1, 2], "B": [0, 2], "C": [0, 0]})

# %%
df3
# Out:
#    A  B  C
# 0  1  0  0
# 1  2  2  0

# %%
df3.any(axis = 'columns') # C[A]
# Out:
# 0    True
# 1    True
# dtype: bool

# %%
df3.any(axis='rows')
# Out:
# A     True
# B     True
# C    False
# dtype: bool

# %%
df3.any()
# Out:
# A     True
# B     True
# C    False
# dtype: bool

# %%
new_df = df[df['Bonus %'] > 5]#, First Name]
new2_df = df[df['Bonus %'] < 5]

# %%
new_df3 = df.loc[df['Salary']>5000]
new_df3
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
new2_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 19       Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 20        Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# ..         ...     ...         ...             ...     ...      ...
# 976     Denise  Female  10/19/1992         5:42 AM  137954    4.195
# 985    Stephen     NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
#
#     Senior Management             Team
# 1                True              NaN
# 4                True  Client Services
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
new_df = df.loc[df['Salary']!= 50000]
new_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# isin() 

options = ['Client Services', 'Product']
new_df = df[df['Team'].isin(options)]
new_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 17       Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18       Diana  Female  10/23/1981        10:27 AM  132940   19.082
# ..         ...     ...         ...             ...     ...      ...
# 974      Harry    Male   8/30/2011         6:31 PM   67656   16.455
# 977      Sarah  Female   12/4/1995         9:16 AM  124566    5.949
# 979     Ernest    Male   7/20/2013         6:41 AM  142935   13.198
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
#
#     Senior Management             Team
# 4                True  Client Services
# 6                True          Product
# ...

# %%
options = ['Client Services', 'Product']
new_df = df.loc[df['Team'].isin(options)]
new_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 17       Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18       Diana  Female  10/23/1981        10:27 AM  132940   19.082
# ..         ...     ...         ...             ...     ...      ...
# 974      Harry    Male   8/30/2011         6:31 PM   67656   16.455
# 977      Sarah  Female   12/4/1995         9:16 AM  124566    5.949
# 979     Ernest    Male   7/20/2013         6:41 AM  142935   13.198
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
#
#     Senior Management             Team
# 4                True  Client Services
# 6                True          Product
# ...

# %%
# ~ not

options = ['Client Services', 'Product']
new_df = df.loc[~df['Team'].isin(options)]
new_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
options = ['Sales']

new_df = df[(df['Gender']=='Male') & (df['Team'].isin(options))]
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 13 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         37 non-null     object
#  1   Gender             39 non-null     object
#  2   Start Date         39 non-null     object
#  3   Last Login Time    39 non-null     object
#  4   Salary             39 non-null     int64
#  5   Bonus %            39 non-null     float64
#  6   Senior Management  37 non-null     object
#  7   Team               39 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.7+ KB

# %%
new_df
# Out:
#       First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 13          Gary   Male   1/27/2008        11:40 PM  109831    5.831
# 45         Roger   Male   4/17/1980        11:32 AM   88010   13.886
# 71        Johnny   Male   11/6/2009         4:23 PM  118172   16.194
# 167  Christopher   Male  12/24/2011        12:22 PM  142178   17.984
# 189     Clarence   Male    5/2/1998         3:16 AM   85700    1.215
# 202        Roger   Male   11/8/1982         2:32 AM  140558    5.084
# 225        Harry   Male   10/1/2015         7:47 PM   64579   15.266
# 257          NaN   Male  11/25/1999         6:16 AM   42676   15.517
# 312       Gerald   Male   4/16/2001        10:09 PM  121604    1.923
# 337         Earl   Male    1/5/2000         5:46 PM   91344    4.035
# 340       Steven   Male   5/12/2009         2:14 PM  113060    2.846
# 371        Larry   Male   8/27/2003         1:00 PM   91133    5.140
# 373      Kenneth   Male   4/13/1999        10:28 PM   81839   12.072
# ...

# %%
n_ df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),
                  index=['mouse', 'rabbit'],
                  columns=['one', 'two', 'three'])

# %%
n_df
# Out:
#         one  two  three
# mouse     1    2      3
# rabbit    4    5      6

# %%
n_df.filter(items=['mouse'], axis=0) # por default são as colunas ...!?
# Out:
#        one  two  three
# mouse    1    2      3

# %%
max
# Out:
# <function max>

# %%
record = {
  
 'Name': ['Ankit', 'Amit', 'Aishwarya', 'Priyanka', 'Priya', 'Shaurya' ],
 'Age': [21, 19, 20, 18, 17, 21],
 'Stream': ['Math', 'Commerce', 'Science', 'Math', 'Math', 'Science'],
 'Percentage': [88, 92, 95, 70, 65, 78] }

# %% [markdown]
# Code #1 : Selecting all the rows from the given dataframe in which ‘Percentage’ is greater than 80 using basic method.

# %%
type(record)
# Out:
# dict

# %%
record['Percentage']
# Out:
# [88, 92, 95, 70, 65, 78]

# %%
#record[record['Percentage']>80] # TypeError: '>' not supported between instances of 'list' and 'int'
# Solution pass to dataframe
dir(record)

# dataframe = record.to_frame().. not exist in dictionary this method

dataframe = pd.DataFrame(record)

# %%
dataframe
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95
# 3   Priyanka   18      Math          70
# 4      Priya   17      Math          65
# 5    Shaurya   21   Science          78

# %%
# Selecting rows based in codition

condition = dataframe[dataframe['Percentage'] > 80]

# %%
condition #del(codition)

# %%
condition
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95

# %% [markdown]
# using loc[].

# %%
condition2 = dataframe.loc[dataframe['Percentage'] > 80]

# %%
condition2
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95

# %% [markdown]
# Code #3 : Selecting all the rows from the given dataframe in which ‘Percentage’ is not equal to 95 using loc[].

# %%
condition3 = dataframe.loc[dataframe['Percentage']!=95]

# %%
condition3
# Out:
#        Name  Age    Stream  Percentage
# 0     Ankit   21      Math          88
# 1      Amit   19  Commerce          92
# 3  Priyanka   18      Math          70
# 4     Priya   17      Math          65
# 5   Shaurya   21   Science          78

# %% [markdown]
# Selecting those rows whose column value is present in the list using isin() method of the dataframe.

# %% [markdown]
# Code #1 : Selecting all the rows from the given dataframe in which ‘Stream’ is present in the options list using basic method.

# %%
dataframe[dataframe['Stream'].notna()]
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95
# 3   Priyanka   18      Math          70
# 4      Priya   17      Math          65
# 5    Shaurya   21   Science          78

# %%
type(dataframe['Stream'])
# Out:
# pandas.core.series.Series

# %%
options = ['Math', 'Science']

# %%
condition_3 = dataframe[dataframe['Stream'].isin(options)]#condition_3 = dataframe[dataframe.isin(options)]

# %%
condition_3
# Out:
#         Name  Age   Stream  Percentage
# 0      Ankit   21     Math          88
# 2  Aishwarya   20  Science          95
# 3   Priyanka   18     Math          70
# 4      Priya   17     Math          65
# 5    Shaurya   21  Science          78

# %% [markdown]
# Code #2 : Selecting all the rows from the given dataframe in which ‘Stream’ is present in the options list using loc[].

# %%
condition_1A = dataframe.loc[dataframe['Stream'] == 'Math']

# %%
condition_1A
# Out:
#        Name  Age Stream  Percentage
# 0     Ankit   21   Math          88
# 3  Priyanka   18   Math          70
# 4     Priya   17   Math          65

# %%
options = ['Math', 'Commerce']
condition_2 = dataframe.loc[dataframe['Stream'].isin(options)]

# %%
condition_2
# Out:
#        Name  Age    Stream  Percentage
# 0     Ankit   21      Math          88
# 1      Amit   19  Commerce          92
# 3  Priyanka   18      Math          70
# 4     Priya   17      Math          65

# %% [markdown]
# Code #3 : Selecting all the rows from the given dataframe in which ‘Stream’ is not present in the options list using .loc[].

# %%
condition_3 = dataframe.loc[~dataframe['Stream'].isin(options)]

# %%
condition_3
# Out:
#         Name  Age   Stream  Percentage
# 2  Aishwarya   20  Science          95
# 5    Shaurya   21  Science          78

# %% [markdown]
# **Selecting rows based on multiple column conditions using '&' operator.**
#
#
# Code #1 : Selecting all the rows from the given dataframe in which ‘Age’ is equal to 21 and ‘Stream’ is present in the options list using basic method

# %%
options = ['Math', 'Science']

# %%
dataframe
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95
# 3   Priyanka   18      Math          70
# 4      Priya   17      Math          65
# 5    Shaurya   21   Science          78

# %%
condition_4 = dataframe[(dataframe['Age'] == 21) &
                         (dataframe['Stream'].isin(options))]

# %%
condition_4
# Out:
#       Name  Age   Stream  Percentage
# 0    Ankit   21     Math          88
# 5  Shaurya   21  Science          78

# %% [markdown]
# Code #2 : Selecting all the rows from the given dataframe in which ‘Age’ is equal to 21 and ‘Stream’ is present in the options list using .loc[].

# %%
condition_5 = dataframe.loc[(dataframe['Age']==21) &
                            (dataframe['Stream'].isin(options))]

# %%
condition_5
# Out:
#       Name  Age   Stream  Percentage
# 0    Ankit   21     Math          88
# 5  Shaurya   21  Science          78
